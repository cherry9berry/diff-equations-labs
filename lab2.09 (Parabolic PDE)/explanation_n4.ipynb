# %% [markdown]
# # ?????????????????? ???????????? ???????????? ???4 (???????????????????????????? ?????????????????? ???? ???????????????????? ??????????????????)
#
# ## ???????????????????? ????????????
#
# **??????????????????:** $$u_t = u_{xx} + t \cosrac{\pi x}{2} \cos 2\pi x + \cos t.$$
# **?????????????????? ??????????????:** $$u_x(0,t) = 1, \quad u(1,t) = \sin t.$$
# **?????????????????? ??????????????:** $$u(x,0) = x - 1 + \cosrac{5\pi x}{2}.$$

# %% [markdown]
# ## ?????? 1. ?????????????????????????????? ??????????????
#
# ???????? $s(x,t)$ ?? $$s_x(0,t) = 1, \quad s(1,t) = \sin t.$$
# ???????????????? ???????????????? ?????????????? $$s(x,t) = x + \sin t - 1.$$

# %% [markdown]
# ## ?????? 2. ?????????? ?????????????????? ?????? $v = u - s$
#
# ??????????????????????: $$s_t = \cos t, \quad s_{xx} = 0.$$
# ?????????????????????? ????????
# $$v_t = v_{xx} + t \cosrac{\pi x}{2} \cos 2\pi x,$$
# ?????????????????? ??????????????: $$v_x(0,t) = 0, \quad v(1,t) = 0,$$
# ?????????????????? ??????????????: $$v(x,0) = \cosrac{5\pi x}{2}.$$

# %% [markdown]
# ## ?????? 3. ?????????????????????? ?????????????? (???????????? ?? 0, ?????????????? ?? 1)
#
# ???????? $$v = X(x)T(t).$$
# ???????????????? $$X'' + \lambda^2 X = 0, \quad X'(0)=0, \quad X(1)=0.$$
# ?????????????????????? ???????????????? $$\lambda_k = rac{\pi(2k-1)}{2},$$
# ?????????????????????? ?????????????? $$X_k(x) = \cos\left(	frac{\pi(2k-1)x}{2}
# ight).$$

# %% [markdown]
# ## ?????? 4. ???????????????????? ???????????????? ????????????
#
# ?????????????????? ??????????????: $$\cosrac{5\pi x}{2} = X_3(x),$$ ???????????? $$	heta_3 = 1.$$
# ???????????????????????????? ????????????????????????:
# $$t \cosrac{\pi x}{2} \cos 2\pi x = \sum_{k=1}^{\infty} \mu_k(t) X_k(x).$$
# ???????????????????????? $$\mu_k(t) = 2t \int_0^1 \cosrac{\pi x}{2} \cos 2\pi x \cos\left(	frac{\pi(2k-1)x}{2}
# ight) dx.$$

# %% [markdown]
# ## ?????? 5. ?????????????????? ?????? $T_k(t)$
#
# ????????????????
# $$T_k' + \lambda_k^2 T_k = \mu_k(t), \quad T_k(0) = 	heta_k.$$
# ?????????????? ??????????????:
# $$T_k(t) = 	heta_k e^{-\lambda_k^2 t} + \int_0^t e^{-\lambda_k^2 (t-	au)} \mu_k(	au) d	au.$$
# ?? ?????????? ???????? ???????????????? ?????????????? ????????: $$T_3(t) = e^{-rac{25\pi^2}{4} t} + \int_0^t e^{-rac{25\pi^2}{4}(t-	au)} \mu_3(	au) d	au.$$

# %% [markdown]
# ## ?????? 6. ???????????????????????? ????????
#
# $$v(x,t) = \sum_{k=1}^{\infty} X_k(x) T_k(t).$$
# ?????? ???????????????????????? ???????????????? ????????????????????
# $$v(x,t) pprox \cosrac{5\pi x}{2} e^{-rac{25\pi^2}{4} t}.$$

# %% [markdown]
# ## ?????? 7. ?????????????????????????? ??????????
#
# ?????????????????????????????? $$u = v + s$$:
# $$u(x,t) = \sum_{k=1}^{\infty} X_k(x) T_k(t) + x + \sin t - 1.$$
# ?????? ?????????????????????????? ?????????? ???????????????????????? ?????????????? ????????????
# $$u(x,t) pprox \cosrac{5\pi x}{2} e^{-rac{25\pi^2}{4} t} + x + \sin t - 1.$$
