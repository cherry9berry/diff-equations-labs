# %% [markdown]
# # ?????????????????? ???????????? ???????????? ???1 (???????????????????????????? ??????????????????)
#
# ## ???????????????????? ????????????
#
# **??????????????????:** $$u_t = u_{xx}.$$
# **??????????????:** $$x \in [1,2], \quad t \ge 0.$$
# **?????????????????? ??????????????:** $$u_x(1,t) = 0, \quad u(2,t) = 0.$$
# **?????????????????? ??????????????:** $$u(x,0) = \cos\!\left(\tfrac{3\pi(x-1)}{2}\right).$$
#
# ???????? ??? ???????????????? ?????????????? $u(x,t)$ ?????????????? ???????????????????? ????????????????????, ???????????????? ???????? ??????????.

# %% [markdown]
# ## ?????? 1. ???????????????????? ?????????????????? ?????????????? ?? ????????????????????
#
# ?????????????????? ?????????????? ?????? ????????????????????, ?????????????? ???????????????? $$s(x,t)=0$$ ?? ???????????????? $$u=v.$$

# %% [markdown]
# ## ?????? 2. ???????????????? ?????????????????? ?? ???????????????????? ??????????????
#
# ?? ???????????? $s=0$ ??????????
# $$v_t = v_{xx}, \qquad v_x(1,t) = 0, \qquad v(2,t) = 0,$$
# $$v(x,0) = \cos\!\left(\tfrac{3\pi(x-1)}{2}\right).$$

# %% [markdown]
# ## ?????? 3. ?????????????????????? ?????????????? ?? ?????????????????????? ????????????????
#
# ???????? $$v = X(x)T(t).$$ ????????????????
# $$\frac{T'}{T} = \frac{X''}{X} = -\lambda^2.$$
# ???????????? ???????????????????????????????:
# $$X'' + \lambda^2 X = 0, \quad X'(1)=0, \quad X(2)=0.$$
# ??????????????: $$X(x) = C\cos\!\left(\lambda(x-1)\right).$$
# ?????????????? $X(2)=0$ ???????? $$\cos\lambda = 0,$$ ????????????
# $$\lambda_k = \frac{\pi(2k-1)}{2}, \qquad X_k(x) = \cos\!\left(\tfrac{\pi(2k-1)(x-1)}{2}\right).$$

# %% [markdown]
# ## ?????? 4. ???????????????????? ???????????????????? ??????????????
#
# ?????????????? ?????????????????????????? ??????????????: $$v(x,t)=\sum_{k=1}^{\infty} X_k(x)T_k(t).$$
# ?????????????????? ?????????????? ???????????????????????? ???? $X_k$:
# $$v(x,0)=\sum_{k=1}^{\infty} \theta_k X_k(x).$$
# ?????? ?????? $$\cos\!\left(\tfrac{3\pi(x-1)}{2}\right)=X_2(x),$$ ?????????? $$\theta_2=1,$$ ?????????????????? ???????????????????????? ?????????? ????????.

# %% [markdown]
# ## ?????? 5. ?????????????????????? ?????????????? $T_k(t)$
#
# ?????? ?????????????? $k$ ???????????????? ??????
# $$T_k' + \lambda_k^2 T_k = 0, \qquad T_k(0)=\theta_k.$$
# ??????????????: $$T_k(t)=\theta_k e^{-\lambda_k^2 t}.$$ ???????????????????????? ?????????????????? ???????? ??? $$T_2(t)=e^{-\frac{9\pi^2}{4}t}.$$

# %% [markdown]
# ## ?????? 6. ???????????? ??????????????
#
# $$v(x,t)=\sum_{k=1}^{\infty} \theta_k X_k(x) e^{-\lambda_k^2 t}=X_2(x)e^{-\lambda_2^2 t}.$$
# ????????, $$v(x,t)=\cos\!\left(\tfrac{3\pi(x-1)}{2}\right)e^{-\frac{9\pi^2}{4}t}.$$

# %% [markdown]
# ## ?????? 7. ?????????????????????????? ??????????
#
# ?????????????????? $u=v$, ?????????????????????????? ??????????????
# $$u(x,t)=\cos\!\left(\tfrac{3\pi(x-1)}{2}\right)e^{-\frac{9\pi^2}{4}t}. $$
# ?????? ?????????????????????????? ??????????????????, ?????????????????? ?? ???????????????????? ????????????????.
