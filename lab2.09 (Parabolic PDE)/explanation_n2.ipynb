# %% [markdown]
# # ?????????????????? ???????????? ???????????? ???2 (???????????????????????????? ?????????????????? ?? ????????????????????)
#
# ## ???????????????????? ????????????
#
# **??????????????????:** $$u_t = u_{xx} + 2u_x.$$
# **??????????????:** $$x \in [0,1], \quad t \ge 0.$$
# **?????????????????? ??????????????:** $$u(0,t) = 0, \quad u_x(1,t) + u(1,t) = 0.$$
# **?????????????????? ??????????????:** $$u(x,0) = e^{-x} \sin\!\left(	frac{5\pi x}{2}
# ight).$$

# %% [markdown]
# ## ?????? 1. ???????????????????? ?????????????????? ??????????????
#
# ?????????????????? ?????????????? ????????????????????, ?????????????? ???????????????? $$s(x,t)=0,$$ ?? $$u=v.$$

# %% [markdown]
# ## ?????? 2. ???????????????????? ???????????????????? $2u_x$
#
# ???????????????????? ???????????? $$u(x,t) = e^{-x} w(x,t).$$
# ?????????? ?????????????????????? ????????????????
# $$w_t = w_{xx} - w,$$
# ?????????????????? ?????????????? ?????????????????????????? ?? $$w(0,t) = 0, \quad w_x(1,t) = 0,$$
# ?????????????????? ??????????????: $$w(x,0) = \sin\!\left(	frac{5\pi x}{2}
# ight).$$

# %% [markdown]
# ## ?????? 3. ?????????????????????? ?????????????? ???????????? ???????????????????????????????
#
# ???????? $$w = X(x)T(t).$$ ????????????????
# $$X'' + \lambda^2 X = 0, \quad X(0) = 0, \quad X'(1) = 0.$$
# ??????????????: $$X_k(x) = \sin\!\left(	frac{\pi(2k-1)x}{2}
# ight), \quad \lambda_k = 	frac{\pi(2k-1)}{2}. $$

# %% [markdown]
# ## ?????? 4. ???????????????????? ???????????????????? ??????????????
#
# ?????????????? $$\sin\!\left(	frac{5\pi x}{2}
# ight)$$ ?????????????????? ?? $X_3(x)$, ??????????????
# $$	heta_3 = 1, \quad 	heta_k = 0 	ext{ ?????? } k
# e 3.$$

# %% [markdown]
# ## ?????? 5. ???????????????????? ?????????????? $T_k(t)$
#
# ?????? ?????????????? $k$ ??????????
# $$T_k' + (\lambda_k^2 + 1) T_k = 0, \quad T_k(0) = 	heta_k.$$
# ??????????????: $$T_k(t) = 	heta_k e^{-(\lambda_k^2 + 1)t}.$$
# ?????????????????? ?????????? ???????? ???????????? $$T_3(t) = e^{-(rac{25\pi^2}{4} + 1)t}.$$

# %% [markdown]
# ## ?????? 6. ???????????????????????????? $w(x,t)$
#
# $$w(x,t) = \sin\!\left(	frac{5\pi x}{2}
# ight) e^{-\left(rac{25\pi^2}{4} + 1
# ight)t}.$$

# %% [markdown]
# ## ?????? 7. ?????????????? ?? $u(x,t)$
#
# ?????????????????? $u = e^{-x} w$, ????????????????
# $$u(x,t) = e^{-x} \sin\!\left(	frac{5\pi x}{2}
# ight) e^{-\left(rac{25\pi^2}{4} + 1
# ight)t}. $$
# ?????????????? ?????????????????????????? ???????? ???????????????? ????????????.
