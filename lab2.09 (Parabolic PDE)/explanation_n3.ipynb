# %% [markdown]
# # ?????????????????? ???????????? ???????????? ???3 (???????????????????????????? ?????????????????? ?? ?????????????????????????? ???????????????????????????? ??????????????????)
#
# ## ???????????????????? ????????????
#
# **??????????????????:** $$u_t = u_{xx} + x - 2 + \cos 2\pi x.$$
# **?????????????????? ??????????????:** $$u_x(0,t) = t, \quad u_x(1,t) = t + 2.$$
# **?????????????????? ??????????????:** $$u(x,0) = x^2 + \cos\pi x.$$

# %% [markdown]
# ## ?????? 1. ?????????? ?????????????????????????????? ??????????????
#
# ?????????? ???????????????? ?????????????????? ???? ????????????????. ???????? $$s(x,t)$$ ?? ??????????????????
# $$s_x(0,t) = t, \quad s_x(1,t) = t + 2.$$
# ?????????????? ??????????: $$s(x,t) = tx + x^2.$$

# %% [markdown]
# ## ?????? 2. ?????????? ?????????????????? ?????? $v = u - s$
#
# ?????????????????? ??????????????????????: $$s_t = x, \quad s_{xx} = 2.$$
# ?????????????????????? ????????
# $$v_t = v_{xx} + \cos 2\pi x.$$
# ?????????????????? ?????????????? ?????????????????? ?? $$v_x(0,t) = 0, \ v_x(1,t) = 0,$$
# ?????????????????? ??????????????: $$v(x,0) = \cos\pi x.$$

# %% [markdown]
# ## ?????? 3. ?????????????????????? ?????????????? ?? ?????????????????????????? ??????????????????
#
# ???????????? ???????????????????????????????:
# $$X'' + \lambda^2 X = 0, \quad X'(0)=0, \quad X'(1)=0.$$
# ?????????????????????? ???????????????? $$\lambda_k = k\pi,$$
# ?????????????????????? ?????????????? $$X_k(x) = \cos k\pi x, \quad k = 0,1,2,\dots$$

# %% [markdown]
# ## ?????? 4. ???????????????????? ???????????????? ????????????
#
# ?????????????????? ??????????????: $$\cos\pi x = X_1(x),$$ ?????????????? $$	heta_1 = 1.$$
# ????????????????????????????: $$\cos 2\pi x = X_2(x)$$, ???????????? $$\mu_2(t) = 1,$$ ?????????????????? $\mu_k(t)$ ?????????? ????????.

# %% [markdown]
# ## ?????? 5. ?????????????????? ?????? $T_k(t)$
#
# ???????????????? ?????????????? ??????
# $$T_k' + \lambda_k^2 T_k = \mu_k(t), \quad T_k(0) = 	heta_k.$$
# ?????? $k=0$: $$T_0' = 0, \ T_0(0)=0.$$
# ?????? $k=1$: $$T_1' + \pi^2 T_1 = 0, \ T_1(0)=1.$$
# ?????? $k=2$: $$T_2' + 4\pi^2 T_2 = 1, \ T_2(0)=0.$$
# ?????? $k \ge 3$: $	heta_k = \mu_k = 0$.

# %% [markdown]
# ### ?????????????? ???????????????????? ??????
#
# $$T_1(t) = e^{-\pi^2 t},$$
# $$T_2(t) = rac{1 - e^{-4\pi^2 t}}{4\pi^2},$$
# $$T_0(t) = 0.$$

# %% [markdown]
# ## ?????? 6. ???????????????????????? ????????
#
# $$v(x,t) = e^{-\pi^2 t} \cos\pi x + rac{1 - e^{-4\pi^2 t}}{4\pi^2} \cos 2\pi x.$$

# %% [markdown]
# ## ?????? 7. ?????????????? ?? $u(x,t)$
#
# ?????????????????? $s(x,t) = tx + x^2$:
# $$u(x,t) = e^{-\pi^2 t} \cos\pi x + rac{1 - e^{-4\pi^2 t}}{4\pi^2} \cos 2\pi x + tx + x^2.$$
