# %% [markdown]
# # ?????????????????? ???????????? ???????????? ???8 (?????????????????????????? ??????????????????, ??????????????????????????)
#
# ## ???????????????????? ????????????
#
# **??????????????????:** $$\Delta u = u_{xx} + u_{yy} = 0.$$
# **??????????????:** ?????????????????????????? $$0 \le x \le 2,\ 0 \le y \le 1.$$
# **?????????????????? ??????????????:** $$u(0,y)=0,\ u(2,y)=2\sin(3\pi y),\ u(x,0)=0,\ u(x,1)=3\sin(\pi x).$$
#
# ???????????????????????????? ???????????????????????? ???? ???????? ????????????????, ?????????????? ???????????????????? ?????????????? ????????????????????????.

# %% [markdown]
# ## ?????? 1. ?????????????????? ???? ?????? ??????????????????
#
# ???????????????????? $$u = u_1 + u_2$$, ?????? ?? ???????????? ?????????????????? ???????????????????????????? ???????????????????????? ???????????? ???? ?????????? ??????????????.

# %% [markdown]
# ## ?????? 2. ?????????????????? ?????? ????????????????
#
# ???????????? ?????????????????? ?????????????????????????? ?????????????????? ?????????????? $$\Delta u = 0$$ ?? ?????? ???? ????????????????????????????.
# ?????? $u_1$: $u_1(0,y)=u_1(2,y)=u_1(x,0)=0$, $u_1(x,1)=3\sin(\pi x)$.
# ?????? $u_2$: $u_2(x,0)=u_2(x,1)=u_2(0,y)=0$, $u_2(2,y)=2\sin(3\pi y)$.

# %% [markdown]
# ## ?????? 3. ?????????????????????? ??????????????
#
# ### ?????????????????? $u_1$
# ???????????????????? ???????????????????? ???????? $$\lambda_k = \tfrac{k\pi}{2},\ X_k(x)=\sin\tfrac{k\pi x}{2},\ Y_k(y)=\sinh\tfrac{k\pi y}{2}.$$
#
# ### ?????????????????? $u_2$
# ???????????????? $$\mu_k = k\pi,\ Y_k(y)=\sin(k\pi y),\ X_k(x)=\sinh(k\pi x).$$

# %% [markdown]
# ## ?????? 4. ???????????????????? ?????????????????? ????????????
#
# ?????????????? ?????? $y=1$ ???????????????? ?? $$A_2 = \frac{3}{\sinh\pi},\ A_k=0\ (k\ne2).$$
# ?????????????? ?????? $x=2$ ???????? $$C_3 = \frac{2}{\sinh(6\pi)},\ C_k=0\ (k\ne3).$$

# %% [markdown]
# ## ?????? 5. ?????????????? ??????????????
#
# $$u_1(x,y) = \frac{3}{\sinh\pi} \sin(\pi x) \sinh(\pi y),$$
# $$u_2(x,y) = \frac{2}{\sinh(6\pi)} \sinh(3\pi x) \sin(3\pi y).$$

# %% [markdown]
# ## ?????? 6. ????????????????????????
#
# ???????????? ?????????????? ??? ?????????? $u = u_1 + u_2$.

# %% [markdown]
# ## ?????? 7. ???????????????? ??????????????
#
# $$u(x,y) = \frac{3}{\sinh\pi} \sin(\pi x) \sinh(\pi y) + \frac{2}{\sinh(6\pi)} \sinh(3\pi x) \sin(3\pi y).$$
